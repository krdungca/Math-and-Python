# %% [markdown]
# Ellipse
#
# two radii.. a and b
#
# a = x-component of radius
#
# b = y-component of radius
#
# $\frac{(y-k)^2}{b^2} + \frac{(x-h)^2}{a^2} - 1 = 0$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# h = 1
# k = 2

# # define the variables
# a = 2
# b = 3

# axlim = np.max((a,b)) + np.max((abs(h),abs(k)))


# x = np.linspace(-axlim,axlim, 100)
# X,Y = np.meshgrid(x,x)
# # calculate the limits of the plot

# ellipse = (((X-h)**2)/a**2) + (((Y-k)**2)/b**2) -1



# plt.contour(X,Y,ellipse,0)
# plt.plot(h,k,'ro')
# plt.axis([-(b-k),k+b,-(a-h),h+2*a])
# plt.gca().set_aspect('equal')

# %%
#vary k from -4 to 4
# vary a from abs(-4) to 4

# h = 0
# b = 4

h = 0 
a = np.linspace(-4,4,8)
fxn_a = abs(a)

k = np.linspace(-4,4,8)
b = 4

x = np.linspace(-4,4,50)
X,Y = np.meshgrid(x,x)

ellipse = (((X-h)**2)/(4)**2) + (((Y-(-4))**2)/b**2) - 1



plt.contour(X,Y,ellipse,0)


# ellipse = (((X-h)**2)/(fxn_a)**2) + (((Y-k)**2)/b**2) -1




# for k_var in np.linspace(-4,4,8):
#     # print(k_var)
#     for a_new in fxn_a:
#         ellipse = (((X-h)**2)/a_new**2) + (((Y-k_var)**2)/b**2) -1
      
#         plt.contour(X,Y,ellipse,0,colors=[0,0,0])

# %%
n = 16
h = 0
k = np.linspace(-4,4,n)
a = abs(k)
b = 4


x = np.linspace(-8,8,100)
X,Y = np.meshgrid(x,x)

for i in range(0,n):
    F = (X-h)**2/a[i]**2 + (Y-k[i])**2/b**2 - 1
    plt.contour(X,Y,F,0,colors=[i/n,0,i/n])

plt.gca().set_aspect('equal')
