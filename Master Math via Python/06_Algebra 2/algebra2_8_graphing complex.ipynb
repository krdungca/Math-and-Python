# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# %%
z = complex(2,3)

# plt.plot(np.real(z),np.imag(z),'ro')
# plt.plot([0,np.real(z)],[0,np.imag(z)],'r')

plt.xlabel('real')
plt.ylabel('imag')
plt.grid()
plt.axis([-4,4,-4,4])

#base number-line
axis = plt.gca()
plt.plot([0,0],[axis.get_xlim()[0],axis.get_xlim()[1]],'k--')
plt.plot([axis.get_ylim()[0],axis.get_ylim()[1]],[0,0],'k--')

#exercises
#graph z1 + z2
#graph z1 * z2

z1 = complex(-3,1)
z2 = complex(-1,1)

#plot z1 and z2
plt.plot([0,np.real(z1)],[0,np.imag(z1)])
plt.plot([0,np.real(z2)],[0,np.imag(z2)])

#plot z1 + z2
z1_add_z2 = z1 + z2
plt.plot([0,np.real(z1_add_z2)],[0,np.imag(z1_add_z2)],'g')

#plot z1 * z2
z1_times_z2 = z1 * z2
plt.plot([0,np.real(z1_times_z2)],[0,np.imag(z1_times_z2)],'y')
